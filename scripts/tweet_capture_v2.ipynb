# %%
# Standard library
import sys
import logging
import datetime, time
import sqlite3
import pickle
import os
import calendar


import pandas as pd

# bioinfobot
sys.path.append("../")
from bioinfobot.utils.paths import TweetAnalysisPaths

# External library
import tweepy

# %%
# creating a tweeter listener
class StreamListener(tweepy.Stream):
    def on_status(self, status):
        print(status.text)
        if status.lang == "en" and "RT".upper() not in status.text:
            stat = status.text
            stat = stat.replace("\n", "")
            stat = stat.replace("\t", "")
            user_id = status.user.id_str
            stat_id = status.id_str
            create = str(status.created_at)
            name = status.user.screen_name
            data = (create, name, user_id, stat_id, stat)

            # TODO: ---------------------
            # NOTE: This needs to be switch (pandas dataframe)
            # Connecting to SQLite3 database
            try:
                db_file = "../../db/bioinfotweet.db"
                conn = sqlite3.connect(db_file, isolation_level=None)
                conn.execute(
                    "PRAGMA journal_mode=wal"
                )  # This will let concurrent read and write to the database.
                c = conn.cursor()
                c.execute(
                    "INSERT INTO tweetscapture (Date, ScreenName, UserID, TweetID, Text) values (?, ?, ?, ?, ?)",
                    data,
                )
                conn.commit()
                cdate = "Tweet inserted at: " + str(datetime.datetime.now())
                logging.info(cdate)
                conn.close()
            except Exception as ex:
                exname = str(ex)
                template = "An exception of type {0} occurred. Arguments:\n{1!r}"
                message = template.format(type(ex).__name__, ex.args)
                logging.info("Sqlite3 database exception occurred.")
                logging.info(message)
            # ---------------------------
            
    def on_error(self, status_code):
        if status_code == 420:
            cdate = "Error code 420 at:" + str(datetime.datetime.now())
            logging.info(cdate)
            logging.info("Sleeping for 15 mins")
            time.sleep(900)
        return False

# %%
# executing code
# Logging configuration
ta_paths = TweetAnalysisPaths()
logging.basicConfig(
    filename=ta_paths.analysis_log,
    level=logging.DEBUG,
    filemode="a",
    format="%(asctime)s - %(levelname)s: %(message)s",
    datefmt="%m/%d/%Y %I:%M:%S %p",
)
logging.getLogger(
    "matplotlib.font_manager"
).disabled = True  # removes matplotlib debugg
logging.info("Started Tweet-analysis")

# %%
# opening API key 

# TODO: This requires a safer and simpler approach (using dotenv)
def _read_cred():
    # this needs to be set as a dot env file
    with open("../../credentials/bioinfobotmain.txt") as f:
        creds = f.readlines()
        consumer_key = creds[0].rstrip()
        consumer_secret = creds[1].rstrip()
        access_token = creds[2].rstrip()
        access_token_secret = creds[3].rstrip()
        return (consumer_key, consumer_secret, access_token, access_token_secret)

def load_twitter_api():
        consumer_key, consumer_secret, access_token, access_token_secret = _read_cred()
        auth = tweepy.OAuth1UserHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)
        return auth

def load_listener():
        consumer_key, consumer_secret, access_token, access_token_secret = _read_cred()
        listener = StreamListener(consumer_key, consumer_secret, access_token, access_token_secret)
        return listener
    
def load_followers(path: str) -> list[str]: 
    """loads followers"""
    if os.path.isfile(path):
        try:
            with open(path, "rb") as followers:
                following = []
                following_dict = pickle.load(followers)
                for key, value in following_dict.items():
                    following.append(value)
        except Exception as ex:
            print(ex)
        return following
    else:
        raise FileNotFoundError("Unable to load followers from file path")

# %%
api_keys = load_twitter_api()
api = tweepy.API(api_keys)
stream = tweepy.Stream(*_read_cred())
following = load_followers("./following.pickle")

# %%
def _parse_tweet_obj(tweet_obj: tweepy.models) -> list[str, float]:
    """
    parses tweeter status reponses and extract the necessary data 
    """
    
    # extracting relevant data
    tweet_text = tweet_obj.full_text.replace("\n", "").replace("\t", "").split()
    tweet_text = " ".join([word for word in tweet_text if not word.startswith("https://t.co/")])
    user_id = tweet_obj.user.id
    status_id = tweet_obj.id_str
    created = str(tweet_obj.created_at.replace(tzinfo=None))
    name = tweet_obj.user.screen_name
    year = tweet_obj.created_at.year
    month = tweet_obj.created_at.month

    # compile into tuple 
    data = (created, name, user_id, status_id, tweet_text, year, month)

    return data

def create_date_range():
    # getting current month and year
    current_month = int(datetime.datetime.today().strftime("%m"))
    current_year = int(datetime.datetime.today().strftime("%Y"))
    last_day =  calendar.monthrange(current_year, current_month)[1]


    # setting a range of dates
    start_date = datetime.datetime(current_year, current_month, 1, 0, 0, 0)
    end_date = datetime.datetime(current_year, current_month, last_day, 0, 0, 0)

    return (start_date, end_date)

def get_tweets():

    # loading keys
    consumer_key, consumer_secret, access_token, access_token_secret = _read_cred()

    # loading followers
    following = load_followers("./following.pickle")

    # setting authentication
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    # generating timeline
    start_date, end_date = create_date_range()

    # opening API
    api = tweepy.API(auth)

    tweets = []
    for follower in following:
        
        try:
            tmp_tweets = api.user_timeline(screen_name=follower, count=10, include_rts=False, tweet_mode="extended")
        except:
            print(f"User {follower} does not exists")
            continue

        for tweet in tmp_tweets:
            tweet_created = tweet.created_at.replace(tzinfo=None)
            if tweet_created < end_date and tweet_created > start_date:
                tweets.append(tweet)

    col_names = ["Date", "ScreenName", "UserID", "TweetID", "Text", "year", "month"]
    tweet_data = list(map(_parse_tweet_obj, tweets))

    tweet_data_df = pd.DataFrame(data=tweet_data, columns=col_names)
    tweet_data_df. tweet_data_df
    return tweet_data_df

# %%
data = get_tweets()
# Out:
# User gwaygenomics does not exists
# User Cbastien_76 does not exists
# User HorizonGenomics does not exists
# User c4vansite does not exists
# User RNAGenomics does not exists
# User Fungal_Genome does not exists
# User ProjectShivom does not exists
# User conesagroup does not exists
# User PataPecnerova does not exists
# User meyersonlab does not exists
# User IndoorEcology does not exists
# User 91Mattmoore does not exists
# User jordaanblok does not exists
# User Thomas_F_Hahn does not exists
# User dasersoft does not exists
# User SSABiostats does not exists
# User jckuga does not exists
# User stephen__doyle does not exists
# User trashystats does not exists
# User murphy2537 does not exists
# User judiehowrylak does not exists
# User jonxhill does not exists
# User BISC_Global_USA does not exists
# User jny5alv does not exists
# User fourmodern does not exists
# User babasaraki01 does not exists
# User SaarunyaGeet does not exists
# User Brookesloci does not exists
# User WGCengage does not exists
# User rachomics does not exists
# User jsalt92 does not exists
# User SanDiegoLifeSci does not exists
# User eannekerr does not exists
# User CC_ClinGenomics does not exists
# User GenomicsInTO does not exists
# User UCB_QB3Genomics does not exists
# User sci_genomics does not exists
# User NCIEpi does not exists
# User Ensemily does not exists
# User sebboeg does not exists
# User Hose_Hiro does not exists
# User FredTurnerDx does not exists
# User 33rdsquare does not exists
# User BIObus_Canada does not exists
# User polledbreeder does not exists
# User WestenbergCFA does not exists
# User RAPiDGenomics does not exists
# User mtn_science does not exists
# User Inra_urgi does not exists
# User GenomicsMed does not exists
# User GenomicsCoffee does not exists
# User emilysinger does not exists
# User CDGenomics2005 does not exists
# User JaneW_Genomics does not exists
# User GenomicsD does not exists
# User indigenomics does not exists
# User DianaBianchiMD does not exists
# User GenomeQuebec does not exists
# User RGIUCalgary does not exists
# User SouthLondon_GMC does not exists
# User DohertyGenomics does not exists
# User TorontoGenomics does not exists
# User SolGenomics2016 does not exists
# User mary_carmichael does not exists
# User muratbaday1 does not exists
# User globusgenomics does not exists
# User carolineporter does not exists
# User drsteventucker does not exists
# User solgenomics does not exists
# User CAUSES_genomics does not exists
# User Marine_Genomics does not exists
# User NeuroGenomics does not exists
# User asiagenomics does not exists
# User DCGenomics does not exists
# User tracegenomics does not exists
# User SportsGenomics does not exists
# User GenomicsEd does not exists
# User KirkegaardEmil does not exists
# User econ_genomics does not exists
# User ewanbirney does not exists
# User GWBradleyLab does not exists
# User GenomicsTopNews does not exists
# User USW_GPU does not exists
# User NeoGenomics does not exists
# User my_helix does not exists
# User PhaseGenomics does not exists
# User NYUGenomics does not exists
# User Genomicsplc does not exists
# User jhuff_genomics does not exists
# User IGAItaly does not exists
# User OxfordGenomics does not exists
# User ScarabGenomics does not exists
# User xrtGenomics does not exists
# User SBUGenomics does not exists
# User EurofinGenomics does not exists
# User claritas4kids does not exists
# User dutchscientist does not exists
# User DIYgenomics does not exists
# User Fish_Genomics does not exists
# User CincyKidsGenomX does not exists
# User ldoroud does not exists
# User MarineGenomics does not exists
# User VergeGenomics does not exists
# User appliedgenomics does not exists
# User igisci does not exists
# User genomicslawyer does not exists
# User ELS_Genetics does not exists
# User EurekaGenomics does not exists
# User generegulation does not exists
# User MechismoNews does not exists
# User ProfJWHolloway does not exists
# User heejungshim does not exists
# User ishengtsai does not exists
# User keithajolley does not exists
# User dipgdata does not exists
# User mdziemann does not exists
# User DrDanielSwan does not exists
# User matt_streisfeld does not exists
# User rvaerle does not exists
# User FranSupek does not exists
# User LionelGuy does not exists
# User sebotic does not exists
# User kieranrcampbell does not exists
# User labmonkey_in_KL does not exists
# User sheppard_lab does not exists
# User Zannah_Du does not exists
# User rhskraus does not exists
# User Color does not exists
# User JinliangYang does not exists
# User mtgholden does not exists
# User fellgernon does not exists
# User GadAbraham1 does not exists
# User adelong does not exists
# User genomicscloud does not exists
# User JacobFDegner does not exists
# User tstinear does not exists
# User mikerappe does not exists
# User blaxterlab does not exists
# User bioinformAnt does not exists
# User ilovechocagar does not exists
# User trajnp does not exists
# User SBGenomics does not exists
# User WeGenomics does not exists
# User drbachinsky does not exists
# User DionCDetterer does not exists
# User BioNagoya does not exists
# User NazeefaFatima does not exists
# User Adam_Bat does not exists
# User GenomicRule does not exists
# User richardslabexe does not exists
# User GenomicChin does not exists
# User GenomeNext does not exists
# User douglasrtaylor does not exists
# User captdrsteph does not exists
# User road2stat does not exists
# User parisienne5577 does not exists
# User LorenzGut does not exists
# User CPGR_SA_Biotech does not exists
# User genomedx does not exists
# User NadineLevinSTS does not exists
# User westmidsgmc does not exists
# User CnidarianGal does not exists
# User deb_jakub does not exists
# User WuXiNextCODE does not exists
# User ClinicalOMICs does not exists
# User lachlancoin does not exists
# User MacrogenLab does not exists
# User MFT_Genomics does not exists
# User genomaint does not exists
# User GenomicPrivacy does not exists
# User proactivesheen does not exists
# User fluidigm does not exists
# User ankushlab does not exists
# User BirdeRunner does not exists
# User nourishedcloud does not exists
# User dansullivanpdx does not exists
# User metababak does not exists
# User gurnit_atwal does not exists
# User SantiagoSchnell does not exists
# User BSCB_Cornell does not exists
# User DrCompBio does not exists
# User iainrobertsblog does not exists
# User kate_evolved does not exists
# User Br33zyGyalLove does not exists
# User beer_mee does not exists
# User amccalltoarms does not exists
# User LibTonio does not exists
# User genome_karthi does not exists
# User David_L_Stern does not exists
# User RoamingGenome does not exists
# User DemonicGenome does not exists
# User CancerDNA does not exists
# User GalabizGenome does not exists
# User FlowGenomeProj does not exists
# User UnlockLifesCode does not exists
# User GenomeInABottle does not exists
# User startupgenome does not exists
# User GenomeWeb does not exists
# User GenomeBC does not exists
# User bbcgenome does not exists
# User GenomeNathan does not exists
# User GenomeRef does not exists
# User FlowGenome does not exists
# User GenomeCanada does not exists
# User GenomeScience does not exists
# User GenomeMedicine does not exists
# User GenomeBrowser does not exists
# User humangenomeorg does not exists
# User GenomeInstitute does not exists
# User jgi does not exists
# User GenomeBiology does not exists
# User genome_gov does not exists
# User rohitfarmer does not exists
# User illumina does not exists
# User ScienceAsk does not exists
# User fedotov_p does not exists
# User naptoon does not exists
# User SerenaRhie does not exists
# User ademartiruli does not exists
# User skyravle does not exists
# User Wholomics does not exists
# User jungwindy does not exists
# User BaderAljaber does not exists
# User wittequeen does not exists
# User erenada does not exists
# User Makragic_bre does not exists
# User Nasser_GH does not exists
# User Alinekolmer does not exists
# User ZnaeW does not exists
# User AlcoveOutsource does not exists
# User akihiro_asahara does not exists
# User aber_bioinf does not exists
# User galaxy001 does not exists
# User copypasteusa does not exists
# User ayanbule does not exists
# User jstynoski does not exists
# User JebelliAmir does not exists
# User arfcarson does not exists
# User kyurek does not exists
# User marklcrowe does not exists
# User serglarionov does not exists
# User dfjenkins3 does not exists
# User danvilarj does not exists
# User bio_hax does not exists
# User iscb_latam does not exists
# User Golgibio does not exists
# User a3_bio does not exists
# User motifbhu does not exists
# User midwestbioinfo does not exists
# User hinaichigo does not exists
# User gungorbudak does not exists
# User g6gTech does not exists
# User ShukkaMethods does not exists
# User genometra does not exists
# User biogeeks does not exists
# User gmanuel89 does not exists
# User synbiotic does not exists
# User adrian0cg does not exists
# User bigsea_t does not exists
# User ohnoseq does not exists
# User DnEvnsYmmt does not exists
# User bdrcindia does not exists
# User corebioinfo does not exists
# User bioinformaticss does not exists
# User BioResearch does not exists
# User SBBioinformatic does not exists
# User Bioinformatic19 does not exists
# User oceanbioinfo does not exists
# User bioinformaticsg does not exists
# User geneticsnerd does not exists
# User e_bioinformatic does not exists
# User Bioinfofan does not exists
# User NBioinformatics does not exists
# User johnstjohn does not exists
# User sylvain_soliman does not exists
# User acetrigger_99 does not exists
# User skwsm does not exists
# User Biointelligence does not exists
# User pingjie does not exists
# User infoHendri does not exists
# User lazo does not exists
# User sounaka does not exists
# User SohrabShah does not exists
# User bicycle1885 does not exists
# User BenoitFelix does not exists
# User isihya does not exists
# User watarunemoto does not exists
# User Matth2t1h does not exists
# User alinedousse does not exists
# User thenoobyork does not exists
# User ColumbiaUCAT does not exists
# User eofrest does not exists
# User KusumiLab does not exists
# User eti_uva_nl does not exists
# User bioinformatix does not exists
# User THAIbioinfo does not exists
# User bicmgims does not exists
# User keperry does not exists
# User bitmask does not exists
# User IanKorf does not exists
# User taka_simone does not exists
# User counsell does not exists
# User jaakvilo does not exists
# User bclaypoole does not exists
# User bioinformatt does not exists
# User mtothen does not exists
# User hague_tim does not exists
# User synobu does not exists
# User rubycosta does not exists
# User GenoCon2 does not exists
# User laufranch does not exists
# User ogishima does not exists
# User rbuels does not exists
# User Mirrcell does not exists
# User GenePoolNews does not exists
# User yuifu does not exists
# User almata does not exists
# User Biomatters does not exists
# User bioinfo2day does not exists
# User josembecerra does not exists
# User hoppydata does not exists
# User BioStarQuestion does not exists
# User SpiralGenetics does not exists
# User stanfordbmi does not exists
# User blakeweb does not exists
# User dtommei does not exists
# User dsm_md does not exists
# User nathanskidmore does not exists
# User vdemario does not exists
# User RayVRoberts does not exists
# User hongiiv does not exists
# User av_artemov does not exists
# User stephwen does not exists
# User Micro_B3 does not exists
# User morgan_it does not exists
# User MolecularLifeSc does not exists
# User c_z does not exists
# User d_kihara does not exists
# User gthorisson does not exists
# User UXBioinformatic does not exists
# User karmel_a does not exists
# User sesejun does not exists
# User q_bioinformatic does not exists
# User BioNF_Frankfurt does not exists
# User delta2323_ does not exists
# User lichtenj does not exists
# User bioperl does not exists
# User DigBioTrain does not exists
# User BioinformaticsL does not exists
# User WMCBioinformati does not exists
# User sbassi does not exists
# User UoS_BioinfCore does not exists
# User bioinformatic22 does not exists
# User DelftBL does not exists
# User bioinfopup does not exists
# User bioinformaclub does not exists
# User bioinformaticsX does not exists
# User bigodatai does not exists
# User BioinformaticsQ does not exists
# User BrainCatalog does not exists
# User MotleyMutt does not exists
# User bioinfo_events does not exists
# User biyoenformatik does not exists
# User MingoBioinf does not exists
# User bioinformgirl does not exists
# User JapanBioinforma does not exists
# User BIOINFORMATICS3 does not exists
# User KBioinformatic does not exists
# User BIF_KMUTT does not exists
# User WGP_informatics does not exists
# User bioinfo_UAEU does not exists
# User bioinfodiary does not exists
# User Bbioinformatics does not exists
# User NortheasternBIC does not exists
# User 4ngs does not exists
# User ClinBioInformtx does not exists
# User Bioinformatics0 does not exists
# User EVirusBioinfC does not exists
# User bio4yu does not exists
# User NBIC_nl does not exists
# User ausbionet does not exists
# User BABSBioinformat does not exists
# User SheffBioinfHub does not exists
# User MSU_BiCEP does not exists
# User Bio_Informatix does not exists
# User GridBio does not exists
# User bio1416_cr does not exists
# User MVSU_Bioinfo does not exists
# User NictaBioinf does not exists
# User Powerofcheez does not exists
# User KarelvanD does not exists
# User UVABioinfo does not exists
# User hdlns_g1255 does not exists
# User victoriambutt does not exists
# User ferrax does not exists
# User Charlietrypsin does not exists
# User IBMstafa does not exists
# User Johnny_Biondo does not exists
# User dritoshi does not exists
# User BioTestConsort does not exists
# User kheartzTV does not exists
# User UBioinformatics does not exists
# User EmmaSimsLUFC does not exists
# User dotandimet does not exists
# User KidrauhlsFaith does not exists
# User jayehmsee does not exists
# User JamalAlorabi does not exists
# User BioInG_ksu does not exists
# User wakehamAMR does not exists
# User WTCMPbix does not exists
# User haematobot does not exists
# User BroadSideways does not exists
# User jmcmichael does not exists
# User mmarchin does not exists
# User RadwaShoukry does not exists
# User menon_kala does not exists
# User PSUbioinfo does not exists
# User tslbioinfo does not exists
# User Rayili does not exists
# User andref1989 does not exists
# User JedMSP does not exists
# User biolinksdir does not exists
# User IUCCBB does not exists
# User ainakosiboyie does not exists
# User arvestad does not exists
# User DavidNohejl does not exists
# User briankoser does not exists
# User BioinfoPapers does not exists
# User supergianinna does not exists
# User torfinnnome does not exists
# User biojc does not exists
# User mjaeckel does not exists
# User JennyTheJoker does not exists
# User BioinformaticBx does not exists
# User showjumper42 does not exists
# User RayanChikhi does not exists
# User bioinfozen does not exists
# User SGregurickNIH does not exists
# User JamesSacco2 does not exists
# User BiologIT does not exists
# User tiagoantao does not exists
# User Chemtech2020 does not exists
# User _tdido_ does not exists
# User HollyKArnold does not exists
# User dzanekmajta does not exists
# User SamLipworth does not exists
# User JTFouquier does not exists
# User genterasocial does not exists
# User Lum_Ramabaja does not exists
# User SEQquestions does not exists
# User KeywanHP does not exists
# User andre_evol does not exists
# User BioNumerics does not exists
# User anaxfotopoulos does not exists
# User aswarren does not exists
# User students_igmm does not exists
# User BU_CNIO does not exists
# User Guillaumejospin does not exists
# User originalberto does not exists
# User KJames_IntBio does not exists
# User Jas_Hughes does not exists
# User SorenStirling does not exists
# User JPRRNews does not exists
# User Jalview does not exists
# User Mo2Dav does not exists
# User nclbsu does not exists
# User iracooke does not exists
# User dritoshien does not exists
# User Aperiomics does not exists
# User IshitaSharan does not exists
# User pfern does not exists
# User S_Foroutan does not exists
# User scientist_me does not exists
# User MolecPath does not exists
# User NanshengChen does not exists
# User AdrianDuong does not exists
# User RSGSpain does not exists
# User jgiannopoulou does not exists
# User inside_dna does not exists
# User rozovr does not exists
# User rdocking does not exists
# User AmaryllisNuc does not exists
# User stefanpiatek does not exists
# User gabepratt does not exists
# User dagahren does not exists
# User dmill96 does not exists
# User BayBIFX does not exists
# User martinmariaj does not exists
# User Fierst_Lab does not exists
# User MDizz06 does not exists
# User alastair_kerr does not exists
# User robertclab does not exists
# User Parabon does not exists
# User RNA3DHub does not exists
# User arneelof does not exists
# User JamesBradley002 does not exists
# User SunitJain does not exists
# User KelPhoto does not exists
# User DFourches does not exists
# User alexwhan does not exists
# User SteveQinEmory does not exists
# User marinkazitnik does not exists
# User odadaj does not exists
# User Pillai_Pri does not exists
# User thejmazz does not exists
# User nikleotide does not exists
# User eabpajarillo does not exists
# User itselijahtai does not exists
# User meissner_t does not exists
# User DemetriPerdikis does not exists
# User blJOg does not exists
# User areejalsheikh does not exists
# User DrCharOskam does not exists
# User Setfelix does not exists
# User GalenWright does not exists
# User shazanfar does not exists
# User whelanfj does not exists
# User kmkocot does not exists
# User jsantoyo does not exists
# User khedkarsupriya does not exists
# User kisunpokharel does not exists
# User RichardMunthali does not exists
# User Sekuwanda does not exists
# User DeannaTeoh does not exists
# User joie_cannon does not exists
# User scubaninja does not exists
# User nicolekusold does not exists
# User markwassy does not exists
# User GaiaTek does not exists
# User Nicola_Lady does not exists
# User sentausa does not exists
# User evodify does not exists
# User PaoloDiTommaso does not exists
# User fooliu does not exists
# User P_Palagi does not exists
# User WillisCD does not exists
# User tnabtaf does not exists
# User timknut does not exists
# User biotechie_com does not exists
# User fiosgenomics does not exists
# User zach_cp does not exists
# User vekutschera does not exists
# User mtwolfinger does not exists
# User doowttam does not exists
# User Qlucore does not exists
# User PittCompSci does not exists
# User IFB_Bioinfo does not exists
# User genvangraff1 does not exists
# User CrystationalBio does not exists
# User GenoSplice does not exists
# User austinadixon does not exists
# User alon_goren does not exists
# User P9ScienceFeed does not exists
# User stephenpanmd does not exists
# User NEdgingtonPhD does not exists
# User kathleenfisch does not exists
# User jtnystrom does not exists
# User eme_laura does not exists
# User Immunogenomics does not exists
# User NJBurgo does not exists
# User Llosent does not exists
# User thierrygosselin does not exists
# User robyn_s_lee does not exists
# User vloux does not exists
# User rodrigoluk does not exists
# User mitramith does not exists
# User dwheelerau does not exists
# User ChrisColdren does not exists
# User JungeAlexander does not exists
# User ARChakravarthy does not exists
# User LonsBio does not exists
# User idowuolawoye does not exists
# User bluebirdi does not exists
# User paulbfrandsen does not exists
# User Jason_Macrander does not exists
# User martinpalazzo does not exists
# User _julien_roux does not exists
# User alaederach does not exists
# User HardwoodGenomic does not exists
# User bio4j does not exists
# User RoxyHorror does not exists
# User Sarri does not exists
# User maxal6 does not exists
# User chrisfall does not exists
# User interactivefly does not exists
# User MattRavenhall does not exists
# User tehancocks does not exists
# User rach_ade does not exists
# User molodyets does not exists
# User jpbopenaccess does not exists
# User biocurator does not exists
# User mygobletorg does not exists
# User aawitney does not exists
# User EMBL_ABR does not exists
# User matthewpocock does not exists
# User markjcowley does not exists
# User InSilicoDB does not exists
# User fran6wol does not exists
# User ElixirNodeUk does not exists
# User RodrigoAldecoa does not exists
# User nyu_informatics does not exists
# User natalicik does not exists
# User robsyme does not exists
# User frogsicles does not exists
# User guilbourque does not exists
# User roy_ronen does not exists
# User biobeth does not exists
# User BioplatformsAus does not exists
# User MarkBoguskiMD does not exists
# User LMDenys does not exists
# User MAFatCRUK does not exists
# User MindtheByte does not exists
# User EmmanuelYera does not exists
# User christopherbare does not exists
# User AustinTanney does not exists
# User dk_barupal does not exists
# User Dereneaton does not exists
# User HelixRecruiting does not exists
# User amcrisan does not exists
# User jonnings does not exists
# User isugif does not exists
# User sbassiEN does not exists
# User estebanarias does not exists
# User benhwhite does not exists
# User lambros_f does not exists
# User richardmleggett does not exists
# User Chuckytah does not exists
# User waywardsyintist does not exists
# User MColebrook does not exists
# User FabienCampagne does not exists
# User Ajwhall does not exists
# User jonathan_beard does not exists
# User useless_ulysses does not exists
# User pcmasuzzo does not exists
# User gatapishichan does not exists
# User kdpru does not exists
# User lelimat does not exists
# User BiddleLab does not exists
# User themarytodd does not exists
# User Carlos_Jall does not exists
# User rintzezelle does not exists
# User simon_t does not exists
# User mrgraeme does not exists
# User DocDer does not exists
# User tanghaibao does not exists
# User gail_l_rosen does not exists
# User yokofakun does not exists
# User Byteman62 does not exists
# User fredebibs does not exists
# User stevepiccolo does not exists
# User ivanhk100 does not exists
# User VivienBonazzi does not exists
# User IGIB_DEL_110007 does not exists
# User AndrewJesaitis does not exists
# User CharlesJolyB does not exists
# User procrastinomics does not exists
# User monsterbashseq does not exists
# User genestack does not exists
# User coxtonyj does not exists
# User wessidepraxis does not exists
# User SarahHCarl does not exists
# User hquesneville does not exists
# User VinCannataro does not exists
# User mcdemarco does not exists
# User discretestates does not exists
# User kiharalab does not exists
# User conrad_halling does not exists
# User megbowman does not exists
# User daweonline does not exists
# User SelFdz does not exists
# User alexeome does not exists
# User philipmach does not exists
# User gau does not exists
# User jameslz does not exists
# User WyWyWa does not exists
# User PhillipCompeau does not exists
# User kihyy does not exists
# User pvtodorov does not exists
# User charlesdanko does not exists
# User karinv does not exists
# User kozo2 does not exists
# User nfeau does not exists
# User KelliJoKuntzman does not exists
# User byzia does not exists
# User eleanorahowe does not exists
# User MadsAlbertsen85 does not exists
# User nicholas_navin does not exists
# User SnjoyNingthousm does not exists
# User sgivan does not exists
# User JonathanSobel1 does not exists
# User smllmp does not exists
# User BarkerLab does not exists
# User agmcarthur does not exists
# User nekton4plankton does not exists
# User marianattestad does not exists
# User chiaracokieng does not exists
# User eupathdb does not exists
# User Svanuytven does not exists
# User akpelinordor does not exists
# User RobAboukhalil does not exists
# User KristaTernus does not exists
# User AlbertVilella does not exists
# User genomecenter does not exists
# User felipealbrecht does not exists
# User stewartetcie does not exists
# User y_bromberg does not exists
# User LauTor83 does not exists
# User fstrozzi does not exists
# User mikaelhuss does not exists
# User leomrtns does not exists
# User BenScruggs does not exists
# User brandstaetter does not exists
# User interzoneboy does not exists
# User ACGT_blog does not exists
# User Miss_Salmonella does not exists
# User estebanpv does not exists
# User JokeReumers does not exists
# User LukaszPK does not exists
# User Genomics_2018 does not exists
# User omictools does not exists
# User mcdonadt does not exists
# User xdopazo does not exists
# User benrjack does not exists
# User davetang31 does not exists
# User niituniversity does not exists
# User AndrewBartletta does not exists
# User OBF_BOSC does not exists
# User genomiss does not exists
# User ayshwaryas does not exists
# User kristiyanto_ does not exists
# User Luke__Ward does not exists
# User ConnectRD does not exists
# User laurastephen does not exists
# User ElinVidevall does not exists
# User lawremi does not exists
# User envisagenics does not exists
# User rmflight does not exists
# User ClinMicrobiom does not exists
# User LilithElina does not exists
# User BanfieldLab does not exists
# User matthewlaird does not exists
# User JVJAI does not exists
# User saltyscientist does not exists
# User cynthiagibas does not exists
# User DocVPhD does not exists
# User nick_harding does not exists
# User druvus does not exists
# User UB_CBLS does not exists
# User shalomfrance does not exists
# User groundwalkergmb does not exists
# User daumari does not exists
# User paulblaser does not exists
# User jacarrico does not exists
# User markrobinsonca does not exists
# User ecerami does not exists
# User hcorrada does not exists
# User EBItraining does not exists
# User benfulton does not exists
# User FOAylward does not exists
# User AhmedMoustafa does not exists
# User codushlaine does not exists
# User FertigLab does not exists
# User gjbarton does not exists
# User housut does not exists
# User nachocaballero does not exists
# User NoahFahlgren does not exists
# User morgantaschuk does not exists
# User genocad does not exists
# User leonpalafox does not exists
# User asherichia does not exists
# User RNajmanovich does not exists
# User SpringerSysBio does not exists
# User yannick__ does not exists
# User seandavis12 does not exists
# User heathermvincent does not exists
# User malachigriffith does not exists
# User oleg_s does not exists
# User TransmitScience does not exists
# User reagank does not exists
# User halovast does not exists
# User RPoretsky does not exists
# User rob_beiko does not exists
# User JuanUgaldeC does not exists
# User juliaweatherby does not exists
# User proteomicsinfo does not exists
# User Lisasheeran does not exists
# User GenomicsIo does not exists
# User jung_gt does not exists
# User vavrusam does not exists
# User scottlyle does not exists
# User MelissaSWarren does not exists
# User DrMicrobeson does not exists
# User BiochemPhD does not exists
# User homolog_us does not exists
# User jermdemo does not exists
# User dzerbino does not exists
# User TrestleJeff does not exists
# User divyamistry does not exists
# User davidjstudholme does not exists
# User sarahmhird does not exists
# User kshameer does not exists
# User bioinfosm does not exists
# User toniher does not exists
# User mjsteinbaugh does not exists
# User gtyrelle does not exists
# User JChrisPires does not exists
# User obigriffith does not exists
# User stuffysour does not exists
# User klmr does not exists
# User BioMath does not exists
# User jimrperkins does not exists
# User VectorBase does not exists
# User insaneJMad does not exists
# User Biopython does not exists
# User alxndrkalinin does not exists
# User PhilippBayer does not exists
# User SAGRudd does not exists
# User jfkelso does not exists
# User timrich does not exists
# User EducatedMicrobe does not exists
# User KateME0 does not exists
# User Nick_Goldman does not exists
# User elyw does not exists
# User alexbowe does not exists
# User fiedawn does not exists
# User aanaqvi does not exists
# User martinmaiers does not exists
# User HPCDan does not exists
# User will_fitzhugh does not exists
# User teeniedeenie does not exists
# User RongChenBioinfo does not exists
# User bioinformer does not exists
# User davisjmcc does not exists
# User sebhtml does not exists
# User bradkohl does not exists
# User Chris_Evelo does not exists
# User bmpvieira does not exists
# User Campbell_JD_PhD does not exists
# User Vanessa__Devine does not exists
# User olgabot does not exists
# User GraveleyLab does not exists
# User bgood does not exists
# User funkycoda does not exists
# User ucsdccbb does not exists
# User ppgardne does not exists
# User INB_Official does not exists
# User yggdrasil13751 does not exists
# User fionabrinkman does not exists
# User daattali does not exists
# User RoxanaDaneshjou does not exists
# User OpenHelix does not exists
# User cupton1 does not exists
# User russo_cristina does not exists
# User Bioinfomatic does not exists
# User DamCou does not exists
# User pedrobeltrao does not exists
# User k8hert does not exists
# User tothur does not exists
# User tjsharpton does not exists
# User infoecho does not exists
# User abacbs does not exists
# User denbiOffice does not exists
# User ToddTaylorRIKEN does not exists
# User VanBUG_ does not exists
# User ucsfbiostat does not exists
# User MelBioInf does not exists
# User obf_news does not exists
# User StructBioinfo does not exists
# User KenyaBioinfo does not exists
# User danmaclean does not exists
# User ISBSIB does not exists
# User BioinformatNews does not exists
# User ncgas does not exists
# User JenaRNA does not exists
# User YorkBioinfo does not exists
# User DTUBioinfo does not exists
# User BioinformLon does not exists
# User KMS_Meltzy does not exists
# User torstenseemann does not exists
# User WU_BioInfo does not exists
# User introspection does not exists
# User iGenomics does not exists
# User BioVice_IBMCP does not exists
# User digitalbio does not exists
# User andrewsu does not exists
# User EarlhamInst does not exists
# User evolscientist does not exists
# User BioInfo does not exists
# User GeneRef does not exists
# User dermitzakis does not exists
# User yuriquintana does not exists
# User RockefellerUniv does not exists
# User HealthITmHealth does not exists
# User Annals_Oncology does not exists
# User wjjessen does not exists
# User UofABioinfoHub does not exists
# User UTEPBIOINFO does not exists
# User uga_iob does not exists
# User BioinformaticsP does not exists
# User chusdonlo does not exists
# User BMC_Bioinforma does not exists
# User MarkGerstein does not exists
# User emotiv does not exists
# User UTKbioinform does not exists
# User TransBioinf does not exists
# User UMKCBioMed does not exists
# User ubc_utrecht does not exists
# User Bioinfodotca does not exists
# User vsbuffalo does not exists
# User genomeresearch does not exists
# User viralnerd does not exists
# User AdaptiveBiotech does not exists
# User AWRgenes does not exists
# User davelunt does not exists
# User bionode does not exists
# User horacio_ps does not exists
# User tdread_emory does not exists
# User intact_project does not exists
# User allysonlister does not exists
# User docdhawad does not exists
# User MolSoft does not exists
# User BioMickWatson does not exists
# User strnr does not exists
# User emblebi does not exists
# User UConn_Bioinfo does not exists
# User hollybik does not exists
# User watsonhaigh does not exists
# User tuuliel does not exists
# User sjackman does not exists
# User AliciaOshlack does not exists
# User JovMaksimovic does not exists
# User DoktrNick does not exists
# User pitman_mark does not exists
# User phdomics does not exists
# User nygenome does not exists
# User Alfons_Valencia does not exists
# User marc_rr does not exists
# User SequentiaBio does not exists
# User MVickySchneider does not exists
# User BioinformaticsB does not exists
# User agapow does not exists
# User rnomics does not exists
# User sjcockell does not exists
# User elvinjestrada does not exists
# User wolfgangkhuber does not exists
# User AviMaayan does not exists
# User pathogenomenick does not exists
# User ngsbioinfo does not exists
# User bioinformatics does not exists
# User BUbioinfo does not exists
# User QIAGENBiox does not exists
# User gedankenstuecke does not exists
# User BioInfoInc does not exists
# User NIAIDBioIT does not exists
# User NCI_NCIP does not exists
# User bioinfblogs does not exists
# User BioinformaticsJ does not exists
# User bioinformatics1 does not exists
# User OHSUBCB does not exists
# User QFAB_Bioinfo does not exists
# User ecSeq does not exists
# User Bioinformatics_ does not exists
# User BioinfoRepos does not exists
# User BiBcn does not exists
# User Bioinformatic does not exists
# KeyboardInterrupt

# %%
data.sort_values(by="Date", ascending=True)
# Out:
#                    Date       ScreenName      UserID              TweetID  \
# 67  2022-07-01 01:38:41        aeharkess  1029867727  1542684080835137538
# 66  2022-07-01 01:44:21        aeharkess  1029867727  1542685507351715840
# 65  2022-07-01 01:47:58        aeharkess  1029867727  1542686419113709568
# 64  2022-07-01 01:51:28        aeharkess  1029867727  1542687298139160576
# 63  2022-07-01 02:08:39        aeharkess  1029867727  1542691624093995009
# ..                  ...              ...         ...                  ...
# 3   2022-07-14 16:22:00  AleMedinaRivera   627852903  1547617418222047235
# 2   2022-07-14 16:38:24  AleMedinaRivera   627852903  1547621546084093959
# 44  2022-07-14 16:57:16        aeharkess  1029867727  1547626291314053126
# 1   2022-07-14 19:00:21  AleMedinaRivera   627852903  1547657268056838145
# 0   2022-07-14 21:59:37  AleMedinaRivera   627852903  1547702380552019968
#
#                                                  Text  year  month
# 67  @MadLoftin You're the people who inspire me ! ...  2022      7
# 66  @mmjulkowska @BraybrookSA Definitely. Seems ha...  2022      7
# 65  @BraybrookSA Definitely. We're fortunate that ...  2022      7
# 64  @BraybrookSA @mmjulkowska Yeah great point. I'...  2022      7
# 63  @may_gun @BraybrookSA Yeah, that's definitely ...  2022      7
# ..                                                ...   ...    ...
# 3   @XiuweiZhang presenting her work on methods to...  2022      7
# 2                                           @sroyyors  2022      7
# 44                      The worst kind of spam email.  2022      7
# 1   Awesome keynote talk by @FurlanLab at @ISCB_Re...  2022      7
# 0   @ISCB_RegSys @mahonylab @AMathelier Is my plea...  2022      7
#
# [68 rows x 7 columns]

# %%
df
# Out:
#                       0                1           2                    3  \
# 0   2022-07-14 21:59:37  AleMedinaRivera   627852903  1547702380552019968
# 1   2022-07-14 19:00:21  AleMedinaRivera   627852903  1547657268056838145
# 2   2022-07-14 16:38:24  AleMedinaRivera   627852903  1547621546084093959
# 3   2022-07-14 16:22:00  AleMedinaRivera   627852903  1547617418222047235
# 4   2022-07-14 15:57:33  AleMedinaRivera   627852903  1547611266050449410
# ..                  ...              ...         ...                  ...
# 63  2022-07-01 02:08:39        aeharkess  1029867727  1542691624093995009
# 64  2022-07-01 01:51:28        aeharkess  1029867727  1542687298139160576
# 65  2022-07-01 01:47:58        aeharkess  1029867727  1542686419113709568
# 66  2022-07-01 01:44:21        aeharkess  1029867727  1542685507351715840
# 67  2022-07-01 01:38:41        aeharkess  1029867727  1542684080835137538
#
#                                                     4     5  6
# 0   @ISCB_RegSys @mahonylab @AMathelier Is my plea...  2022  7
# 1   Awesome keynote talk by @FurlanLab at @ISCB_Re...  2022  7
# 2                                           @sroyyors  2022  7
# 3   @XiuweiZhang presenting her work on methods to...  2022  7
# 4   @sroyyors 's @ISCB_RegSys Keynote on Cell type...  2022  7
# ..                                                ...   ... ..
# 63  @may_gun @BraybrookSA Yeah, that's definitely ...  2022  7
# 64  @BraybrookSA @mmjulkowska Yeah great point. I'...  2022  7
# 65  @BraybrookSA Definitely. We're fortunate that ...  2022  7
# 66  @mmjulkowska @BraybrookSA Definitely. Seems ha...  2022  7
# 67  @MadLoftin You're the people who inspire me ! ...  2022  7
#
# [68 rows x 7 columns]
